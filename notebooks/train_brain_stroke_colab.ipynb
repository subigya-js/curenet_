# %% [markdown]
# # CureNet brain stroke CT training
# Run this notebook with a Colab GPU. It downloads the TEKNOFEST-2021 Kaggle packaging, audits and deduplicates images, trains EfficientNetV2-B0, evaluates the held-out data, and exports the model. Dataset reuse rights must be confirmed before redistribution or publication.

# %%
# !nvidia-smi
import tensorflow as tf
print('TensorFlow:', tf.__version__)
print('GPU:', tf.config.list_physical_devices('GPU'))
# Out:
# /bin/bash: nvidia-smi: command not found
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 get_ipython().system('nvidia-smi')
# ----> 2 import tensorflow as tf
#       3 print('TensorFlow:', tf.__version__)
#       4 print('GPU:', tf.config.list_physical_devices('GPU'))
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
![ -d curenet_ ] || git clone https://github.com/subigya-js/curenet_.git
# %cd curenet_/ml_services
# !python -m pip install -q -r requirements-train.txt

# %% [markdown]
# ## Optional smoke test
# Uncomment this first if you want to validate the pipeline before the full run.

# %%
# !python -m stroke_ml.train --quick-check --output-dir artifacts/stroke_ct_smoke

# %%
# !python -m stroke_ml.train --output-dir artifacts/stroke_ct_v2

# %%
import json
from pathlib import Path
results = json.loads(Path('artifacts/stroke_ct_v2/metrics.json').read_text())
print(json.dumps(results, indent=2))

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir -p /content/drive/MyDrive/curenet-stroke-v2
# !cp -r artifacts/stroke_ct_v2/* /content/drive/MyDrive/curenet-stroke-v2/
print('Saved model, manifest, audit, predictions, and metrics to Google Drive.')
